# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')
df.columns = ['Date', 'Amount', 'Category', 'Description']
display(df.head())
# Out:
#          Date  Amount    Category Description
# 0  2026-01-07     0.5   groceries       kinza
# 1  2025-12-07     3.5  resturants         saj
# 2   2025-12-7     0.3   groceries         NaN
# 3  2026-01-07     5.0  resturants         NaN

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
display(df)
# Out:
#         Date  Amount    Category Description
# 0 2026-01-07     0.5   groceries       kinza
# 1 2025-12-07     3.5  resturants         saj
# 2 2025-12-07     0.3   groceries         NaN
# 3 2026-01-07     5.0  resturants         NaN

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import questionary
#
# ModuleNotFoundError: No module named 'questionary'

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 7
#       1 questionary.select(
#       2     "What do you want to do?",
#       3     choices=[
#       4         'Order a pizza',
#       5         'Make a reservation',
#       6         'Ask for opening hours'
# ----> 7     ]).ask()
#
# File /opt/anaconda3/lib/python3.13/site-packages/questionary/question.py:64, in Question.ask(self, patch_stdout, kbi_msg)
#      51 """Ask the question synchronously and return user response.
#      52
#      53 Args:
#    (...)
#      60     `Any`: The answer from the question.
#      61 """
#      63 try:
# ---> 64     return self.unsafe_ask(patch_stdout)
#      65 except KeyboardInterrupt:
#      66     print("{}".format(kbi_msg))
#
# File /opt/anaconda3/lib/python3.13/site-packages/questionary/question.py:89, in Question.unsafe_ask(self, patch_stdout)
# ...
